# %%
import pandas as pd

# %%
df_LA = pd.read_csv('data_science_jobs_indeed_LA.csv', delimiter=';', encoding='Windows-1251')
df_SD = pd.read_csv('data_science_jobs_indeed_SD.csv', delimiter=';', encoding='Windows-1251')
df_SF = pd.read_csv('data_science_jobs_indeed_SF.csv', delimiter=';', encoding='Windows-1251')

# %%
df_LA
# Out:
#                                             Job Title  \
# 0                            Principal Data Scientist
# 1                                    Data Scientist I
# 2                                 C-17 Data Scientist
# 3                                      Data Scientist
# 4                               Senior Data Scientist
# 5                             Fandango-Data Scientist
# 6                               Senior Data Scientist
# 7                                      Data Scientist
# 8                               Data Scientist Intern
# 9                           Data Scientist, Analytics
# 10                                  Data Scientist II
# 11                                     Data Scientist
# 12                                 Sr. Data Scientist
# 13                                     Data Scientist
# 14                                     Data Scientist
# 15                                     Data Scientist
# ...

# %%
df_LA.describe()
# Out:
#              Job Title  Company Name     Job City Job Rating Job Post Date
# count               50            50           50         50            50
# unique              29            45           20         17            16
# top     Data Scientist  NBCUniversal  Los Angeles       None           30+
# freq                17             3           19         13            28

# %%
df_SD
# Out:
#                                              Job Title  \
# 0                                 Staff Data Scientist
# 1                     Staff Data Scientist - Analytics
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                Senior Data Scientist
# ..                                                 ...
# 136  Regional Head of Business Development - AI & M...
# 137  Senior Research Scientist / Engineer - Machine...
# 138                    Manager, Statistical Programmer
# 139  Lead Analytic Scientist – (Applied AI and Mach...
# 140                   Principal Statistical Programmer
#
#                   Company Name   Job City Job Rating Job Post Date
# 0                       Intuit  San Diego        4.2             1
# 1                       Intuit  San Diego        4.2             1
# 2               Veyo Logistics  San Diego        2.3             1
# ...

# %%
df_SD.describe()
# Out:
#              Job Title Company Name   Job City Job Rating Job Post Date
# count              141          141        141        141           141
# unique             115           79          6         18            17
# top     Data Scientist     Qualcomm  San Diego       None           30+
# freq                10           14        119         31            89

# %%
df_SF
# Out:
#                                       Job Title  \
# 0                    Data Scientist, Admissions
# 1            Data Scientist - San Francisco, CA
# 2                                Data Scientist
# 3                                Data Scientist
# 4                       Clinical Data Scientist
# ..                                          ...
# 495                Senior Health Data Analyst I
# 496                  Data Science Product Owner
# 497                      Director, Data Science
# 498                   Machine Learning Engineer
# 499  Director of Data Science, Lending Products
#
#                                Company Name       Job City Job Rating  \
# 0                              Y Combinator  San Francisco       None
# 1          Pacific Gas And Electric Company  San Francisco        3.9
# 2    University of California San Francisco  San Francisco        4.2
# 3                                  Opendoor  San Francisco        2.9
# ...

# %%
df_SF.describe()
# Out:
#              Job Title Company Name       Job City Job Rating Job Post Date
# count              500          500            500        500           500
# unique             298          224             38         23            24
# top     Data Scientist     Facebook  San Francisco        4.2           30+
# freq                72           40            193        117           353
